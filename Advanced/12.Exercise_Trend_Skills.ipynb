# %% [markdown]
# # Exercise - Investigate Trending Skills

# %%
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

df = pd.read_csv('C:/Users/jhonn/Downloads/data_jobs.csv')

#Cleaning the date 
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
def clean_list (skill_list):
    if pd.notna(skill_list):
        return ast.literal_eval(skill_list)
df['job_skills'] = df['job_skills'].apply(clean_list)

# %%
df.head(2)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
#
#                    job_location           job_via job_schedule_type  \
# 0                 Watertown, CT   via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States         NaN
# 1                  False                 False         Mexico         NaN
#
#    salary_year_avg  salary_hour_avg                company_name  \
# ...

# %%
df['month'] = df['job_posted_date'].dt.month

# %%
df.head(2)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
#
#                    job_location           job_via job_schedule_type  \
# 0                 Watertown, CT   via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States         NaN
# 1                  False                 False         Mexico         NaN
#
#    salary_year_avg  salary_hour_avg                company_name  \
# ...

# %%
df['year'] = df['job_posted_date'].dt.year

# %%
df_exploded = df.explode('job_skills')
df_exploded.head(1)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
#
#     job_location          job_via job_schedule_type  job_work_from_home  \
# 0  Watertown, CT  via Work Nearby         Full-time               False
#
#         search_location     job_posted_date  job_no_degree_mention  \
# 0  Texas, United States 2023-06-16 13:44:15                  False
#
#    job_health_insurance    job_country salary_rate  salary_year_avg  \
# 0                 False  United States         NaN              NaN
#
#    salary_hour_avg          company_name job_skills job_type_skills  month  \
# 0              NaN  Boehringer Ingelheim       None             NaN      6
#
#    year
# 0  2023

# %%
df_exploded_1 = df_exploded[df_exploded['job_title_short']=='Data Analyst'].copy()

# %%
df_exploded_1.head(1)
# Out:
#   job_title_short     job_title                  job_location  \
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
#
#             job_via job_schedule_type  job_work_from_home search_location  \
# 1  via BeBee México         Full-time               False          Mexico
#
#       job_posted_date  job_no_degree_mention  job_health_insurance  \
# 1 2023-01-14 13:18:07                  False                 False
#
#   job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 1      Mexico         NaN              NaN              NaN
#
#                  company_name job_skills  \
# 1  Hewlett Packard Enterprise          r
#
#                                      job_type_skills  month  year
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...      1  2023

# %%
df_da_pivot = df_exploded_1.pivot_table(index='month',columns='job_skills',aggfunc='size', fill_value=0)
meses_dict = {
    1: 'Enero', 2: 'Febrero', 3: 'Marzo', 4: 'Abril', 5: 'Mayo', 6: 'Junio',
    7: 'Julio', 8: 'Agosto', 9: 'Septiembre', 10: 'Octubre', 11: 'Noviembre', 12: 'Diciembre'
}

df_da_pivot.index = df_da_pivot.index.map(meses_dict)

df_da_pivot
# Out:
# job_skills  airflow  airtable  alteryx  angular  angular.js  ansible  apl  \
# month
# Enero           197        17      551       63           2       20    2
# Febrero         169         2      448       49           0       14    1
# Marzo           181         4      442       34           0       23    6
# Abril           155         4      413       22           0       11    8
# Mayo            128         8      310       30           0       19    9
# Junio           164        14      393       29           0       14    9
# Julio           207         4      366       15           0        8    5
# Agosto          197         3      413       21           0       12   10
# Septiembre      118         4      317       21           0       14    3
# Octubre         173        11      350       40           0       19    0
# Noviembre       169         7      293       24           0       19    0
# Diciembre       144        10      274       28           0       13    0
# ...

# %%
df_da_pivot.plot(kind='line')
# Out:
# <Axes: xlabel='month'>

# %%
top_5_skills = df_exploded_1['job_skills'].value_counts().head(5).index

# %%
df_da_pivot[top_5_skills].plot(kind='line')
plt.title('Top 5 skills monthly for D.A.')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # SAMPLE and COPY

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datasets import load_dataset

df = pd.read_csv('C:/Users/jhonn/Downloads/data_jobs.csv')

#Cleaning the date 
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

df = pd.read_csv('C:/Users/jhonn/Downloads/data_jobs.csv')
df.head(2)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
#
#                    job_location           job_via job_schedule_type  \
# 0                 Watertown, CT   via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# 0               False  Texas, United States  2023-06-16 13:44:15
# 1               False                Mexico  2023-01-14 13:18:07
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States         NaN
# 1                  False                 False         Mexico         NaN
#
#    salary_year_avg  salary_hour_avg                company_name  \
# ...

# %%
# a sample of the DF

df.sample(10)
# Out:
#        job_title_short                                          job_title  \
# 614247   Data Engineer                                 Lead Data Engineer
# 469233    Data Analyst                      Junior/Medior Data Analyst HR
# 41267     Data Analyst  Information Security Advisor - Data Discovery ...
# 140169    Data Analyst                    Data Analyst Financial Services
# 422300    Data Analyst                                       Data Analyst
# 687106  Data Scientist             Data Scientist (4500 USD/Mes) [Remote]
# 424000    Data Analyst                 data quality analyst - los angeles
# 705773    Data Analyst                                       Data Analyst
# 724198   Data Engineer                             Data Engineer - Remote
# 756131  Data Scientist  Data Science (AI/Machine Learning & NLP) Inter...
#
#                                             job_location  \
# 614247                                     Nashville, TN
# ...

# %%
df.sample(10, random_state=(42))
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
# 183426           Data Analyst
# 287790           Data Analyst
# 541983           Data Analyst
# 416896         Data Scientist
# 780907          Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
# 183426                                       Data Analyst
# 287790                                       Data Analyst
# 541983                   Data Analyst, Cloud Systems Jobs
# 416896             Alternant Actuariat & Data Science H/F
# ...

# %%
# use the copy method because operations could affect the original dataset. That's not what u want


df_alteredna = df.copy()

# %%
id(df_alteredna) == id(df)
# Out:
# False
